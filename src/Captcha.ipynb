# %%
import numpy as np
from matplotlib.pyplot import imshow
import cv2
import glob
import os
import imutils
from PIL import Image, ImageEnhance, ImageFilter, ImageOps
from sklearn.model_selection import train_test_split

# %%
image_list = []
image_name_list = []

filename = "../data/test/image.png"

for file in glob.glob("../data/Imagens/*"):
    image = Image.open(file).convert("L")
    image_list.append(image)
    
    image_name = os.path.split(os.path.splitext(file)[0])[1]
    image_name_list.append(image_name)
    
# imshow(np.asarray(image_list[0]))

for file in glob.glob(filename):
    image = Image.open(file).convert("L")
    image_list.append(image)

imshow(np.asarray(image_list[-1]))
print(len(image_list))
# Out:
# 1881

# %%
pil_image_list = []

# %matplotlib inline
for image in image_list:
    enhancer = ImageEnhance.Contrast(image)
    enhancer = enhancer.enhance(1.0)
    pixel_matrix = image.load()
    
    # create threshold
    for column in range(0, image.height):
        for row in range(0, image.width):
            if pixel_matrix[row, column] != 0:
                pixel_matrix[row, column] = 255

    # stray line and pixel removal
    for column in range(1, image.height - 1):
        for row in range(1, image.width - 1):
            if pixel_matrix[row, column] == 0 \
                and pixel_matrix[row, column - 1] == 255 and pixel_matrix[row, column + 1] == 255:
                pixel_matrix[row, column] = 255
            if pixel_matrix[row, column] == 0 \
                and pixel_matrix[row - 1, column] == 255 and pixel_matrix[row + 1, column] == 255:
                pixel_matrix[row, column] = 255
    pil_image_list.append(image)                
    
imshow(np.asarray(pil_image_list[0]))

# %%
image_cv_list = []

for image in pil_image_list:
    image = np.array(image)
    image = cv2.cvtColor(image, cv2.COLOR_GRAY2BGR)
    (h, w) = image.shape[:2]
    if w > h:
        image = imutils.resize(image, width=150)

        # otherwise, the height is greater than the width so resize
        # along the height
    else:
        image = imutils.resize(image, height=150)
    print(image.shape)
    padW = int(10)
    padH = int(10)
    image = cv2.copyMakeBorder(image, padH, padH, padW, padW,
            cv2.BORDER_CONSTANT, value=(255, 255, 255, 255))
    
    image_cv = np.array(image)
    image_cv_list.append(image)

imshow(image_cv_list[0])
# Out:
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)
# (25, 150, 3)

# %%
imshow(image_cv_list[5])

# %%
print(len(image_cv_list))
image_cv_list_1 = image_cv_list[:940]
print(len(image_cv_list[:941]))
image_cv_list_2 = image_cv_list[940:1882]
print(len(image_cv_list[941:1882]))
# Out:
# 1881
# 941
# 940

# %%
threshold_image_list = []

for image in image_cv_list_1:
    
    # crop image
    crop = image

    (rows, cols, depth) = crop.shape

    color = 255 * 3

    for row in range(rows):
        for col in range(cols):
            pixel = crop[row][col]
            (r, g, b) = pixel.tolist()

            if color > (r + g + b):
                color = r + g + b

    for row in range(rows):
        for col in range(cols):
            pixel = crop[row][col]
            (r, g, b) = pixel.tolist()
            c = (r + g + b)

            if c != color:
                crop[row][col] = (255, 255, 255)

            else:
                crop[row][col] = (0, 0, 0)
                
#     image = cv2.resize(crop, None, fx=15, fy=15, interpolation=cv2.INTER_LINEAR)
    image = cv2.fastNlMeansDenoising(crop, None, 40, 3, 30)
    image = cv2.threshold(image, 128, 255, cv2.THRESH_TRUNC)[1]
    image = cv2.resize(image, None, fx=5, fy=5, interpolation=cv2.INTER_LINEAR)
    image = cv2.medianBlur(image, 5)
    image = cv2.threshold(image, 128, 255, cv2.THRESH_TRUNC)[1]
                
    threshold_image_list.append(image)
    
imshow(threshold_image_list[0])

# %%
for image in image_cv_list_2:
    
    # crop image
    crop = image

    (rows, cols, depth) = crop.shape

    color = 255 * 3

    for row in range(rows):
        for col in range(cols):
            pixel = crop[row][col]
            (r, g, b) = pixel.tolist()

            if color > (r + g + b):
                color = r + g + b

    for row in range(rows):
        for col in range(cols):
            pixel = crop[row][col]
            (r, g, b) = pixel.tolist()
            c = (r + g + b)

            if c != color:
                crop[row][col] = (255, 255, 255)

            else:
                crop[row][col] = (0, 0, 0)
                
#     image = cv2.resize(crop, None, fx=15, fy=15, interpolation=cv2.INTER_LINEAR)
    image = cv2.fastNlMeansDenoising(crop, None, 34, 3, 30)
    image = cv2.threshold(image, 128, 255, cv2.THRESH_TRUNC)[1]
    image = cv2.resize(image, None, fx=5, fy=5, interpolation=cv2.INTER_LINEAR)
    image = cv2.medianBlur(image, 5)
    image = cv2.threshold(image, 128, 255, cv2.THRESH_TRUNC)[1]
                
    threshold_image_list.append(image)
    
imshow(threshold_image_list[0])

# %%
resized_image_list = []

scale_percent = 10 # percent of original size
# width = int(threshold_image_list[0].shape[1] * scale_percent / 100)
# height = int(threshold_image_list[0].shape[0] * scale_percent / 100)
width = 160
height = 48
dim = (width, height)
for image in threshold_image_list:
    image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
    img = cv2.resize(image, dim, interpolation=cv2.INTER_LINEAR)
    blackwhite = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)
    resized_image_list.append(blackwhite[1][10:40, 18:153])

# %%
imshow(resized_image_list[6])
resized_image_list[6].shape
# Out:
# (30, 135)

# %%
imshow(resized_image_list[5])

# %%
for (i, cv_image) in enumerate(resized_image_list):
    cv2.imwrite("../data/generated_images/%s.png"%(image_name_list[i]), cv_image)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-14-2b8dd0dcbb6a> in <module>
#       1 for (i, cv_image) in enumerate(resized_image_list):
# ----> 2     cv2.imwrite("../data/generated_images/%s.png"%(image_name_list[i]), cv_image)
#
# IndexError: list index out of range

# %%
import skimage.measure
import skimage.color

letters_list = []

(labels, total) = skimage.measure.label(resized_image_list[-1], background=0, return_num=True, connectivity=2)

images = [np.uint8(labels==i) * 255 for i in range(total) if np.uint8(labels==i).sum() > 10]

img = skimage.color.label2rgb(labels, bg_color=[1,1,1])
color = (0.0, 1.0, 0.0)

for i in range(6):
    contours = cv2.findContours(resized_image_list[-1].copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    print(contours)

    (x, y, w, h) = cv2.boundingRect(contours[0])

    half_width = int(w/6)
    if i == 0:
        img = cv2.rectangle(img, (x+2,y), (x+half_width+2, y+h), color, 1)
        letters_list.append((x+2, y, half_width, h))
    else:
        img = cv2.rectangle(img, (i*(half_width+1),y), ((i+1)*(half_width+1), y+h), color, 1)
        letters_list.append((i*(half_width+1), y, half_width, h))

imshow((img*255).astype(np.uint8))
print(letters_list)
# Out:
# (array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), [array([[[  0,   0]],
#
#        [[  0,  29]],
#
#        [[134,  29]],
#
#        [[134,   0]]], dtype=int32)], array([[[-1, -1, -1, -1]]], dtype=int32))
# (array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), [array([[[  0,   0]],
#
#        [[  0,  29]],
#
#        [[134,  29]],
#
#        [[134,   0]]], dtype=int32)], array([[[-1, -1, -1, -1]]], dtype=int32))
# (array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), [array([[[  0,   0]],
#
#        [[  0,  29]],
#
#        [[134,  29]],
#
#        [[134,   0]]], dtype=int32)], array([[[-1, -1, -1, -1]]], dtype=int32))
# (array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), [array([[[  0,   0]],
#
#        [[  0,  29]],
#
#        [[134,  29]],
#
#        [[134,   0]]], dtype=int32)], array([[[-1, -1, -1, -1]]], dtype=int32))
# (array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), [array([[[  0,   0]],
#
#        [[  0,  29]],
#
#        [[134,  29]],
#
#        [[134,   0]]], dtype=int32)], array([[[-1, -1, -1, -1]]], dtype=int32))
# (array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), [array([[[  0,   0]],
#
#        [[  0,  29]],
#
#        [[134,  29]],
#
#        [[134,   0]]], dtype=int32)], array([[[-1, -1, -1, -1]]], dtype=int32))
# [(2, 0, 22, 30), (23, 0, 22, 30), (46, 0, 22, 30), (69, 0, 22, 30), (92, 0, 22, 30), (115, 0, 22, 30)]

# %%
contours_image_list = []

for image in threshold_image_list:
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    gray = cv2.copyMakeBorder(gray, 8, 8, 8, 8, cv2.BORDER_REPLICATE)
    thresh = cv2.threshold(gray, 128, 255, cv2.THRESH_TRUNC)[1]
    # imshow(thresh)

    letter_image_regions = []

    contours = cv2.findContours(thresh.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    contours = contours[0] if imutils.is_cv2() else contours[1]

    for contour in contours:
        (x, y, w, h) = cv2.boundingRect(contour)

        if ((w / h) > 1.25):
            half_width = int(w/2)
            letter_image_regions.append((x, y, half_width, h))
            letter_image_regions.append((x + half_width, y, half_width, h))
        else:
            letter_image_regions.append((x, y, w, h))
print(letter_image_regions)
#     contours_image_list.append(cv2.drawContours(thresh, contours, -1, (0,255,0), 3))
# Out:
# [(0, 0, 433, 241), (433, 0, 433, 241)]

# %%
jorge = []
for i in resized_image_list[:-1]:
    image = np.expand_dims(i, axis=2)
    jorge.append(image)
data = np.array(jorge, dtype="float") / 255.0
labels = np.array(image_name_list)
(x_train, x_test, y_train, y_test) = train_test_split(data, labels, test_size=0.20, random_state=0)

# %%
print(data.shape)
print(labels.shape)
# Out:
# (1880, 30, 135, 1)
# (1880,)

# %%
from sklearn.preprocessing import LabelBinarizer

lb = LabelBinarizer().fit(y_train)
y_train = lb.transform(y_train)
y_test = lb.transform(y_test)

# %%
import pickle
MODEL_LABELS_FILENAME = "model_labels.dat"

with open(MODEL_LABELS_FILENAME, "wb") as f:
    pickle.dump(lb, f)

# %%
MODEL_FILENAME = "captcha_model.hdf5"

# %%
from keras.models import Sequential
from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.layers.core import Flatten, Dense, Dropout

model = Sequential()

# # First convolutional layer with max pooling
# model.add(Conv2D(32, (5, 5), input_shape=(30, 175, 1), activation="relu"))
# model.add(MaxPooling2D(pool_size=(2, 2)))

# # Second convolutional layer with max pooling
# model.add(Conv2D(50, (5, 5), activation="relu"))
# model.add(MaxPooling2D(pool_size=(2, 2)))

# # Hidden layer with 700 nodes
# model.add(Flatten())
# model.add(Dense(1000, activation="relu"))
# # model.add(Dense(800, activation="relu"))

model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(30, 135, 1)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))


# Output layer with 32 nodes (one for each possible letter/number we predict)
# model.add(Dense(1504, activation="softmax"))
model.add(Flatten())

model.add(Dropout(0.3))
model.add(Dense(32, activation='relu'))
model.add(Dense(1504, activation='softmax'))

# Ask Keras to build the TensorFlow model behind the scenes
model.compile(loss="categorical_crossentropy", optimizer="rmsprop", metrics=["accuracy"])

# Train the neural network
model.fit(x_train, y_train, validation_data=(x_test,y_test), batch_size=32, epochs=50,verbose=1)

# Save the trained model to disk
model.save(MODEL_FILENAME)
# Out:
# Train on 1504 samples, validate on 376 samples
# Epoch 1/50
# 1504/1504 [==============================] - 6s 4ms/step - loss: 7.3269 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 2/50
# 1504/1504 [==============================] - 5s 3ms/step - loss: 7.3218 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 3/50
# 1504/1504 [==============================] - 5s 3ms/step - loss: 7.3214 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 4/50
# 1504/1504 [==============================] - 5s 3ms/step - loss: 7.3214 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 5/50
# 1504/1504 [==============================] - 5s 3ms/step - loss: 7.3213 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 6/50
# 1504/1504 [==============================] - 5s 3ms/step - loss: 7.3208 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 7/50
# 1504/1504 [==============================] - 5s 3ms/step - loss: 7.3064 - accuracy: 0.0013 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 8/50
# 1504/1504 [==============================] - 5s 3ms/step - loss: 7.1279 - accuracy: 0.0013 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 9/50
# 1504/1504 [==============================] - 5s 4ms/step - loss: 6.4586 - accuracy: 0.0100 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 10/50
# 1504/1504 [==============================] - 5s 4ms/step - loss: 5.2851 - accuracy: 0.0605 - val_loss: 0.0000e+00 - val_accuracy: 0.0027
# Epoch 11/50
# 1504/1504 [==============================] - 5s 3ms/step - loss: 3.8270 - accuracy: 0.1922 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 12/50
# 1504/1504 [==============================] - 5s 3ms/step - loss: 2.4560 - accuracy: 0.3916 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 13/50
# 1504/1504 [==============================] - 5s 3ms/step - loss: 1.5808 - accuracy: 0.5758 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 14/50
# 1504/1504 [==============================] - 5s 3ms/step - loss: 0.9664 - accuracy: 0.7161 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 15/50
# 1504/1504 [==============================] - 5s 4ms/step - loss: 0.6052 - accuracy: 0.8152 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 16/50
# 1504/1504 [==============================] - 6s 4ms/step - loss: 0.4476 - accuracy: 0.8557 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 17/50
# 1504/1504 [==============================] - 5s 3ms/step - loss: 0.3221 - accuracy: 0.8963 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 18/50
# 1504/1504 [==============================] - 5s 3ms/step - loss: 0.2628 - accuracy: 0.9202 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 19/50
# 1504/1504 [==============================] - 5s 3ms/step - loss: 0.1920 - accuracy: 0.9362 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 20/50
# 1504/1504 [==============================] - 5s 3ms/step - loss: 0.1657 - accuracy: 0.9448 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 21/50
# 1504/1504 [==============================] - 5s 3ms/step - loss: 0.1328 - accuracy: 0.9541 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 22/50
# 1504/1504 [==============================] - 5s 3ms/step - loss: 0.1231 - accuracy: 0.9568 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 23/50
# 1504/1504 [==============================] - 5s 3ms/step - loss: 0.0931 - accuracy: 0.9694 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 24/50
# 1504/1504 [==============================] - 5s 3ms/step - loss: 0.0774 - accuracy: 0.9767 - val_loss: 0.0000e+00 - val_accuracy: 0.0027
# Epoch 25/50
# 1504/1504 [==============================] - 5s 3ms/step - loss: 0.0843 - accuracy: 0.9694 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 26/50
# 1504/1504 [==============================] - 5s 3ms/step - loss: 0.0645 - accuracy: 0.9814 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 27/50
# 1504/1504 [==============================] - 5s 3ms/step - loss: 0.0445 - accuracy: 0.9840 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 28/50
# 1504/1504 [==============================] - 5s 4ms/step - loss: 0.0541 - accuracy: 0.9767 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 29/50
# 1504/1504 [==============================] - 5s 3ms/step - loss: 0.0487 - accuracy: 0.9827 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 30/50
# 1504/1504 [==============================] - 5s 3ms/step - loss: 0.0404 - accuracy: 0.9880 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 31/50
# 1504/1504 [==============================] - 5s 3ms/step - loss: 0.0524 - accuracy: 0.9814 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 32/50
# 1504/1504 [==============================] - 5s 3ms/step - loss: 0.0383 - accuracy: 0.9887 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 33/50
# 1504/1504 [==============================] - 5s 3ms/step - loss: 0.0423 - accuracy: 0.9874 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 34/50
# 1504/1504 [==============================] - 5s 3ms/step - loss: 0.0318 - accuracy: 0.9867 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 35/50
# 1504/1504 [==============================] - 5s 3ms/step - loss: 0.0506 - accuracy: 0.9840 - val_loss: 0.0000e+00 - val_accuracy: 0.0053
# Epoch 36/50
# 1504/1504 [==============================] - 5s 3ms/step - loss: 0.0257 - accuracy: 0.9914 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 37/50
# 1504/1504 [==============================] - 5s 3ms/step - loss: 0.0369 - accuracy: 0.9907 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 38/50
# 1504/1504 [==============================] - 5s 3ms/step - loss: 0.0174 - accuracy: 0.9934 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 39/50
# 1504/1504 [==============================] - 5s 3ms/step - loss: 0.0273 - accuracy: 0.9914 - val_loss: 0.0000e+00 - val_accuracy: 0.0027
# Epoch 40/50
# 1504/1504 [==============================] - 5s 3ms/step - loss: 0.0245 - accuracy: 0.9914 - val_loss: 0.0000e+00 - val_accuracy: 0.0027
# Epoch 41/50
# 1504/1504 [==============================] - 5s 3ms/step - loss: 0.0173 - accuracy: 0.9940 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 42/50
# 1504/1504 [==============================] - 5s 3ms/step - loss: 0.0206 - accuracy: 0.9920 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 43/50
# 1504/1504 [==============================] - 5s 3ms/step - loss: 0.0234 - accuracy: 0.9920 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 44/50
# 1504/1504 [==============================] - 5s 3ms/step - loss: 0.0191 - accuracy: 0.9920 - val_loss: 0.0000e+00 - val_accuracy: 0.0027
# Epoch 45/50
# 1440/1504 [===========================>..] - ETA: 0s - loss: 0.0143 - accuracy: 0.9937

# %%
from keras.models import load_model

with open(MODEL_LABELS_FILENAME, "rb") as f:
    lb = pickle.load(f)

# Load the trained neural network
model = load_model(MODEL_FILENAME)

# %%
letter_image_regions = sorted(letters_list, key=lambda x: x[0])

    # Create an output image and a list to hold our predicted letters
image = resized_image_list[-1]
output = cv2.merge([image] * 3)

# %%
predictions = []
# for letter_bounding_box in letter_image_regions:
#     # Grab the coordinates of the letter in the image
#     x, y, w, h = letter_bounding_box

#     # Extract the letter from the original image with a 2-pixel margin around the edge
#     letter_image = image[y - 2:y + h + 2, x - 2:x + w + 2]
    
#     print(letter_image)

#     # Turn the single image into a 4d list of images to make Keras happy
#     letter_image = np.expand_dims(letter_image, axis=2)
#     letter_image = np.expand_dims(letter_image, axis=0)

#     # Ask the neural network to make a prediction
#     prediction = model.predict(letter_image)

#     # Convert the one-hot-encoded prediction back to a normal letter
#     letter = lb.inverse_transform(prediction)[0]
#     predictions.append(letter)

#     # draw the prediction on the output image
#     cv2.rectangle(output, (x - 2, y - 2), (x + w + 4, y + h + 4), (0, 255, 0), 1)
#     cv2.putText(output, letter, (x - 5, y - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.55, (0, 255, 0), 2)
print(resized_image_list[-1].shape)
imshow(resized_image_list[-1])
letter_image = np.expand_dims(resized_image_list[-1], axis=2)
letter_image = np.expand_dims(letter_image, axis=0)

# Ask the neural network to make a prediction
prediction = model.predict(letter_image)
letter = lb.inverse_transform(prediction)[0]
predictions.append(letter)

# Print the captcha's text
captcha_text = "".join(predictions)
print("CAPTCHA text is: {}".format(captcha_text))
